# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset = pd.read_csv('G:/ML programs/Machine-learning-programs/NLP/titanic.csv')

# %%
X = dataset.iloc[:,[3,4,5,6,7]].values
y = dataset.iloc[:,1].values

# %%
pd.DataFrame(X)
# Out:
#                                                      0       1    2  3  4
# 0                              Braund, Mr. Owen Harris    male   22  1  0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38  1  0
# 2                               Heikkinen, Miss. Laina  female   26  0  0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35  1  0
# 4                             Allen, Mr. William Henry    male   35  0  0
# 5                                     Moran, Mr. James    male  NaN  0  0
# 6                              McCarthy, Mr. Timothy J    male   54  0  0
# 7                       Palsson, Master. Gosta Leonard    male    2  3  1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27  0  2
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female   14  1  0
# 10                     Sandstrom, Miss. Marguerite Rut  female    4  1  1
# 11                            Bonnell, Miss. Elizabeth  female   58  0  0
# ...

# %%
temp = pd.DataFrame(X[:,[0,1,2,3,4]])

# %%
temp[0].value_counts()
temp[1].value_counts()
temp[2].value_counts()
temp[3].value_counts()
temp[4].value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: 4, dtype: int64

# %%
temp[0].isnull().sum()
temp[1].isnull().sum()
temp[2].isnull().sum()
temp[3].isnull().sum()
# Out:
# 0
